# %%
import pandas as pd

# %%
ratings = pd.read_csv("Ratings.csv", encoding='latin-1')

# %%
ratings
# Out:
#          User-ID         ISBN  Book-Rating
# 0         276725   034545104X            0
# 1         276726   0155061224            5
# 2         276727   0446520802            0
# 3         276729   052165615X            3
# 4         276729   0521795028            6
# ...          ...          ...          ...
# 1149775   276704   1563526298            9
# 1149776   276706   0679447156            0
# 1149777   276709   0515107662           10
# 1149778   276721   0590442449           10
# 1149779   276723  05162443314            8
#
# [1149780 rows x 3 columns]

# %%
books = pd.read_csv("Books.csv", encoding='latin-1')
books.head()
# Out:
# C:\Users\SAICOM\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
rating_books=pd.merge(ratings,books,on="ISBN")

# %%
rating_books.head()
# Out:
#    User-ID        ISBN  Book-Rating            Book-Title Book-Author  \
# 0   276725  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 1     2313  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 2     6543  034545104X            0  Flesh Tones: A Novel  M. J. Rose
# 3     8680  034545104X            5  Flesh Tones: A Novel  M. J. Rose
# 4    10314  034545104X            9  Flesh Tones: A Novel  M. J. Rose
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                2002  Ballantine Books
# 3                2002  Ballantine Books
# 4                2002  Ballantine Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/034545104X.0...
# 3  http://images.amazon.com/images/P/034545104X.0...
# 4  http://images.amazon.com/images/P/034545104X.0...

# %%
rating_books_sample = rating_books.sample(frac=.01, random_state=1) 
rating_books_sample.shape
# Out:
# (10311, 10)

# %%
rating_books_pivot = rating_books_sample.pivot_table(index='Book-Title', columns='User-ID', values='Book-Rating').fillna(0)
rating_books_pivot
# Out:
# User-ID                                             254     432     507     \
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# User-ID                                             625     638     726     \
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# User-ID                                             730     805     834     \
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# User-ID                                             876     ...  278314  \
# Book-Title                                                  ...
#  Garfield Bigger and Better (Garfield (Numbered...     0.0  ...     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0  ...     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0  ...     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0  ...     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0  ...     0.0
# ...                                                    ...  ...     ...
# \O\" Is for Outlaw"                                    0.0  ...     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0  ...     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0  ...     0.0
# e                                                      0.0  ...     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0  ...     0.0
#
# User-ID                                             278418  278554  278563  \
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# User-ID                                             278582  278663  278771  \
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# User-ID                                             278838  278843  278851
# Book-Title
#  Garfield Bigger and Better (Garfield (Numbered...     0.0     0.0     0.0
#  Good Wives: Image and Reality in the Lives of ...     0.0     0.0     0.0
#  Little Comic Shop of Horrors (Give Yourself Go...     0.0     0.0     0.0
#  Summonings: Books of Magic, Vol. 2                    0.0     0.0     0.0
# ' Mein verwundetes Herz'. Das Leben der Lilli J...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
# \You're Okay, It's Just a Bruise\": A Doctor's ...     0.0     0.0     0.0
# \\"N\"\" Is for Noose (Thorndike Large Print Ge...     0.0     0.0     0.0
# e                                                      0.0     0.0     0.0
# Ã?Ã?ber die Pflicht zum Ungehorsam gegen den ...     0.0     0.0     0.0
#
# [8531 rows x 5231 columns]

# %%
# Import NearestNeighbors
from sklearn.neighbors import NearestNeighbors

# Build NearestNeighbors Object
model_nn = NearestNeighbors(metric='cosine', algorithm='brute', n_neighbors=7, n_jobs=-1)

# Fit the NearestNeighbor
model_nn.fit(rating_books_pivot)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine', n_jobs=-1, n_neighbors=7)

# %%
# Get top 10 nearest neighbors 
indices=model_nn.kneighbors(rating_books_pivot.loc[['10 Secrets for Success and Inner Peace']], 5, return_distance=False)

# Print the recommended books
print("Recommended Books:")
print("==================")
for index, value in enumerate(rating_books_pivot.index[indices][0]):
    print((index+1),". ",value)
# Out:
# Recommended Books:
# ==================
# 1 .  10 Secrets for Success and Inner Peace
# 2 .  Sorcerer's Son
# 3 .  Sosa : An Autobiography
# 4 .  Soul Harvest: The World Takes Sides (Left Behind No. 4)
# 5 .  Sorceress of Darshiva (Malloreon (Paperback Random House))
# C:\Users\SAICOM\AppData\Local\Temp/ipykernel_17556/3125339938.py:7: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   for index, value in enumerate(rating_books_pivot.index[indices][0]):
